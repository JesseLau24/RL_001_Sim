# %%
# 完整最终版 LifeSimEnv
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd

class LifeSimEnv(gym.Env):
    metadata = {"render.modes": ["human"]}

    def __init__(self,
                 init_cash=10000,
                 init_health=100,
                 max_days=365*80,
                 labor_income=100,
                 labor_health_loss=1,
                 spec_gain=500,
                 spec_loss=700,
                 spec_prob=0.5,
                 spec_health_loss=0.5,
                 rest_recover=2,
                 deposit_rate=0.0001,
                 debt_rate=0.0005):

        super(LifeSimEnv, self).__init__()

        # === 参数 ===
        self.init_cash = init_cash
        self.init_health = init_health
        self.max_days = max_days
        self.labor_income = labor_income
        self.labor_health_loss = labor_health_loss
        self.spec_gain = spec_gain
        self.spec_loss = spec_loss
        self.spec_prob = spec_prob
        self.spec_health_loss = spec_health_loss
        self.rest_recover = rest_recover
        self.deposit_rate = deposit_rate
        self.debt_rate = debt_rate

        # === 状态空间 (现金, 健康, 天数) ===
        self.observation_space = spaces.Box(
            low=np.array([-np.inf, 0, 0], dtype=np.float32),
            high=np.array([np.inf, 100, self.max_days], dtype=np.float32),
            dtype=np.float32
        )

        # === 动作空间 (0=休息, 1=劳动, 2=投机) ===
        self.action_space = spaces.Discrete(3)

        # === 内部状态 ===
        self.cash = None
        self.health = None
        self.day = None

        # 日志
        self.episode_log = None
        self.all_episode_logs = []

    def reset_episode_log(self):
        """初始化单轮 episode 日志"""
        self.episode_log = {
            "days_alive": None,  # None 表示还没活过一天
            "work_days": 0,
            "spec_days": 0,
            "rest_days": 0,
            "final_cash": None
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        # 初始化状态
        self.cash = float(self.init_cash)
        self.health = float(self.init_health)
        self.day = 0

        # 初始化日志
        self.reset_episode_log()

        obs = np.array([self.cash, self.health, self.day], dtype=np.float32)
        return obs, {}

    def step(self, action):
        self.day += 1
        reward = 1.0  # 存活奖励

        # === 行为逻辑 ===
        if action == 0:  # 休息
            self.health = min(100, self.health + self.rest_recover)
            self.episode_log["rest_days"] += 1

        elif action == 1:  # 劳动
            self.cash += self.labor_income
            self.health -= self.labor_health_loss
            self.episode_log["work_days"] += 1

        elif action == 2:  # 投机
            if np.random.rand() < self.spec_prob:
                self.cash += self.spec_gain
            else:
                self.cash -= self.spec_loss
            self.health -= self.spec_health_loss
            self.episode_log["spec_days"] += 1

        # === 利息计算 ===
        if self.cash > 0:
            self.cash *= (1 + self.deposit_rate)
        elif self.cash < 0:
            self.cash *= (1 + self.debt_rate)

        # === 更新日志 ===
        self.episode_log["days_alive"] = self.day
        self.episode_log["final_cash"] = self.cash

        # === 状态 ===
        obs = np.array([self.cash, self.health, self.day], dtype=np.float32)

        # === 检查是否结束 ===
        done = False
        if self.health <= 0 or self.day >= self.max_days:
            done = True
            # ✅ 只在 episode 真正结束时记录日志，避免存 0 值
            self.record_episode()

        truncated = False
        return obs, reward, done, truncated, {}

    def render(self, mode="human"):
        print(f"Day {self.day} | Cash: {self.cash:.2f} | Health: {self.health:.1f}")

    def record_episode(self):
        """保存当前 episode 日志"""
        if self.episode_log is not None and self.episode_log["days_alive"] is not None:
            self.all_episode_logs.append(self.episode_log.copy())

    def save_logs_to_csv(self, filename="life_logs.csv"):
        """保存所有 episode 日志到 CSV"""
        if len(self.all_episode_logs) == 0:
            print("⚠️ 没有日志可保存！")
            return
        df = pd.DataFrame(self.all_episode_logs)
        df.to_csv(filename, index=False)
        print(f"✅ Logs saved to {filename}")

# %%
# 第二个 cell: 训练 RecurrentPPO 智能体，并记录每轮人生

import torch
from stable_baselines3 import PPO
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor

# === 1. 包装环境，使用 DummyVecEnv ===
def make_env():
    return LifeSimEnv()

env = DummyVecEnv([make_env])
env = VecMonitor(env)  # 自动记录 episode reward 等信息

# === 2. 定义 RecurrentPPO 智能体 ===
policy_kwargs = dict(
    net_arch=[64, 64],  # LSTM 前的 MLP 层
    lstm_hidden_size=64,
    n_lstm_layers=1,
)

model = RecurrentPPO(
    "MlpLstmPolicy",
    env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    batch_size=32,
    n_steps=128,       # 每个 rollout 的步数
    learning_rate=3e-4,
    gamma=0.99,
    device="cuda"
)

# === 3. 自定义 Callback，用于记录每轮人生 ===
from stable_baselines3.common.callbacks import BaseCallback

class EpisodeLoggerCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_rollout_end(self):
        # rollout 结束时，不记录，这里主要在每个 episode done 时记录
        pass

    def _on_step(self) -> bool:
        # 检查每个 env 是否 done
        infos = self.locals.get("infos", [])
        for i, info in enumerate(infos):
            if "episode" in info:
                # episode done，调用环境记录日志
                self.training_env.envs[i].record_episode()
        return True

callback = EpisodeLoggerCallback()

# === 4. 开始训练 ===
total_timesteps = 100_000  # 可以根据算力调整
model.learn(total_timesteps=total_timesteps, callback=callback)

# === 5. 训练结束后，保存模型和日志 ===
model.save("lifesim_recurrentppo")

# 保存日志到 CSV
env.envs[0].save_logs_to_csv("lifesim_training_results.csv")
# Out:
# Using cpu device
# ----------------------------
# | time/              |     |
# |    fps             | 793 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 128 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0032632817 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 7.24e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 100          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 194          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 384         |
# | train/                  |             |
# |    approx_kl            | 0.009696759 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00362     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00527    |
# |    value_loss           | 189         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0069879377 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00547     |
# |    value_loss           | 184          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 640          |
# | train/                  |              |
# |    approx_kl            | 0.0033495892 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 0.000334     |
# |    value_loss           | 179          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 768          |
# | train/                  |              |
# |    approx_kl            | 0.0044960007 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.9         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 180          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 0.003409991 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 177         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0036990354 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.1         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000873    |
# |    value_loss           | 174          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 263           |
# |    iterations           | 9             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 1152          |
# | train/                  |               |
# |    approx_kl            | 0.00022095349 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 98.9          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | 0.000294      |
# |    value_loss           | 171           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 10           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0022182525 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.4         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000891    |
# |    value_loss           | 168          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 11           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 1408         |
# | train/                  |              |
# |    approx_kl            | 0.0027288543 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.42e+03     |
# |    ep_rew_mean          | 1.42e+03     |
# | time/                   |              |
# |    fps                  | 262          |
# |    iterations           | 12           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0035426235 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 88           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 161          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.42e+03     |
# |    ep_rew_mean          | 1.42e+03     |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 13           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0073259207 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.955       |
# |    explained_variance   | -0.00131     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.6         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00637     |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 14           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0040730885 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84           |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 155          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 15          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 1920        |
# | train/                  |             |
# |    approx_kl            | 0.019934766 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -1.47e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000989   |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 16          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.000489546 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00158    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.6        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00287     |
# |    value_loss           | 149         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 17           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 2176         |
# | train/                  |              |
# |    approx_kl            | 0.0034435475 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.9         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00427     |
# |    value_loss           | 146          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 18           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0040777875 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.00674      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.8         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 143          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 19           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 2432         |
# | train/                  |              |
# |    approx_kl            | 0.0023264908 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.371        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 50.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 20          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.020246949 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0544      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 88.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 21           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 2688         |
# | train/                  |              |
# |    approx_kl            | 0.0013057566 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000436     |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 22          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.011358316 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.8        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 135         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 23           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 2944         |
# | train/                  |              |
# |    approx_kl            | 0.0060987775 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 132          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 24          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.009717254 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 129         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 25           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 3200         |
# | train/                  |              |
# |    approx_kl            | 0.0006863456 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.9         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000479    |
# |    value_loss           | 126          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 26          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.009319022 |
# |    clip_fraction        | 0.00625     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 123         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 27           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 3456         |
# | train/                  |              |
# |    approx_kl            | 0.0010374533 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.8         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 4.83e-05     |
# |    value_loss           | 121          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 28           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0029550255 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.9         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 29          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 3712        |
# | train/                  |             |
# |    approx_kl            | 0.003519889 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.4        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 30          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.010311875 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00564    |
# |    value_loss           | 113         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 31           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 3968         |
# | train/                  |              |
# |    approx_kl            | 0.0050040786 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.3         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 110          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 32           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0010589259 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.9         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000521    |
# |    value_loss           | 108          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 33           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4224         |
# | train/                  |              |
# |    approx_kl            | 0.0014800876 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.1         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000934    |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 34          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.012956543 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 35           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 4480         |
# | train/                  |              |
# |    approx_kl            | 0.0043273745 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.1         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 100          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 36          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.003353137 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.1        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00122    |
# |    value_loss           | 97.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 37           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 4736         |
# | train/                  |              |
# |    approx_kl            | 0.0015055509 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.5         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000916    |
# |    value_loss           | 95.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 38           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0070850314 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.93        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.1         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 93           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 39           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4992         |
# | train/                  |              |
# |    approx_kl            | 0.0088272635 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.3         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00526     |
# |    value_loss           | 90.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 40          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.010590237 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.877      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 88.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 41          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 0.013919203 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.1        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 86.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 42          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.005717098 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.1        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 84          |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 886           |
# |    ep_rew_mean          | 886           |
# | time/                   |               |
# |    fps                  | 258           |
# |    iterations           | 43            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 5504          |
# | train/                  |               |
# |    approx_kl            | 0.00067130337 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.833        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 21.3          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 0.000655      |
# |    value_loss           | 81.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 44          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.009306097 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 79.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 45           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 5760         |
# | train/                  |              |
# |    approx_kl            | 0.0071698823 |
# |    clip_fraction        | 0.152        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.825       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.9         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00812     |
# |    value_loss           | 77.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 46           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0011885064 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.3         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00137      |
# |    value_loss           | 75.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 886        |
# |    ep_rew_mean          | 886        |
# | time/                   |            |
# |    fps                  | 259        |
# |    iterations           | 47         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 6016       |
# | train/                  |            |
# |    approx_kl            | 0.00822031 |
# |    clip_fraction        | 0.0203     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.85      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.8       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00106   |
# |    value_loss           | 73.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 48          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006494709 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 71.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 49          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 6272        |
# | train/                  |             |
# |    approx_kl            | 0.019343287 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.2        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 69.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 50           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0007318491 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.765       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.8         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000135    |
# |    value_loss           | 67.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 886         |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 51          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6528        |
# | train/                  |             |
# |    approx_kl            | 0.005288302 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.768      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 65.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 52           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0009747199 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.3         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000452    |
# |    value_loss           | 63.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 53           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 6784         |
# | train/                  |              |
# |    approx_kl            | 0.0008188039 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.7         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00097     |
# |    value_loss           | 61.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 886           |
# |    ep_rew_mean          | 886           |
# | time/                   |               |
# |    fps                  | 260           |
# |    iterations           | 54            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 6912          |
# | train/                  |               |
# |    approx_kl            | 0.00054764375 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.658        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 22.2          |
# |    n_updates            | 530           |
# |    policy_gradient_loss | 0.000353      |
# |    value_loss           | 59.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 55           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 7040         |
# | train/                  |              |
# |    approx_kl            | 0.0043088896 |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.711       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 57.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 886          |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 56           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0047640367 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0            |
# ...
# |    ep_rew_mean          | 2.05e+03    |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 765         |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 97920       |
# | train/                  |             |
# |    approx_kl            | 0.009354076 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00803    |
# |    n_updates            | 7640        |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05e+03   |
# |    ep_rew_mean          | 2.05e+03   |
# | time/                   |            |
# |    fps                  | 231        |
# |    iterations           | 766        |
# |    time_elapsed         | 423        |
# |    total_timesteps      | 98048      |
# | train/                  |            |
# |    approx_kl            | 0.01283041 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.812     |
# |    explained_variance   | -5.76      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00684   |
# |    n_updates            | 7650       |
# |    policy_gradient_loss | -0.00698   |
# |    value_loss           | 0.000391   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 2.05e+03     |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 767          |
# |    time_elapsed         | 423          |
# |    total_timesteps      | 98176        |
# | train/                  |              |
# |    approx_kl            | 0.0027361368 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.759       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0128       |
# |    n_updates            | 7660         |
# |    policy_gradient_loss | 0.00351      |
# |    value_loss           | 0.00023      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.05e+03      |
# |    ep_rew_mean          | 2.05e+03      |
# | time/                   |               |
# |    fps                  | 231           |
# |    iterations           | 768           |
# |    time_elapsed         | 424           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00063156383 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.756        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000771     |
# |    n_updates            | 7670          |
# |    policy_gradient_loss | 0.000582      |
# |    value_loss           | 0.000137      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.05e+03      |
# |    ep_rew_mean          | 2.05e+03      |
# | time/                   |               |
# |    fps                  | 231           |
# |    iterations           | 769           |
# |    time_elapsed         | 424           |
# |    total_timesteps      | 98432         |
# | train/                  |               |
# |    approx_kl            | 0.00015236251 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.762        |
# |    explained_variance   | 0.807         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0191        |
# |    n_updates            | 7680          |
# |    policy_gradient_loss | 0.00076       |
# |    value_loss           | 0.0396        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 2.05e+03    |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 770         |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 98560       |
# | train/                  |             |
# |    approx_kl            | 0.003093882 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0168      |
# |    n_updates            | 7690        |
# |    policy_gradient_loss | -0.000629   |
# |    value_loss           | 0.000569    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 2.05e+03    |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 771         |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 98688       |
# | train/                  |             |
# |    approx_kl            | 0.007574366 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00126    |
# |    n_updates            | 7700        |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 0.000181    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 2.05e+03     |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 772          |
# |    time_elapsed         | 426          |
# |    total_timesteps      | 98816        |
# | train/                  |              |
# |    approx_kl            | 0.0070356103 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.858       |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.032       |
# |    n_updates            | 7710         |
# |    policy_gradient_loss | -0.00784     |
# |    value_loss           | 0.000225     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.1e+03    |
# |    ep_rew_mean          | 2.1e+03    |
# | time/                   |            |
# |    fps                  | 231        |
# |    iterations           | 773        |
# |    time_elapsed         | 426        |
# |    total_timesteps      | 98944      |
# | train/                  |            |
# |    approx_kl            | 0.00451054 |
# |    clip_fraction        | 0.0586     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.798     |
# |    explained_variance   | -0.0108    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0154    |
# |    n_updates            | 7720       |
# |    policy_gradient_loss | -0.00557   |
# |    value_loss           | 8.7e-05    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.1e+03      |
# |    ep_rew_mean          | 2.1e+03      |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 774          |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 99072        |
# | train/                  |              |
# |    approx_kl            | 0.0052439487 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.845       |
# |    explained_variance   | -0.0328      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 273          |
# |    n_updates            | 7730         |
# |    policy_gradient_loss | -0.00571     |
# |    value_loss           | 622          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.1e+03      |
# |    ep_rew_mean          | 2.1e+03      |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 775          |
# |    time_elapsed         | 428          |
# |    total_timesteps      | 99200        |
# | train/                  |              |
# |    approx_kl            | 0.0053350837 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | -11.2        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00496     |
# |    n_updates            | 7740         |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 0.0376       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1e+03     |
# |    ep_rew_mean          | 2.1e+03     |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 776         |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.010249089 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | -4.2e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 0.0035      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1e+03     |
# |    ep_rew_mean          | 2.1e+03     |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 777         |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 99456       |
# | train/                  |             |
# |    approx_kl            | 0.021270726 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | -2.57       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0464     |
# |    n_updates            | 7760        |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.1e+03      |
# |    ep_rew_mean          | 2.1e+03      |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 778          |
# |    time_elapsed         | 430          |
# |    total_timesteps      | 99584        |
# | train/                  |              |
# |    approx_kl            | 0.0042569903 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -4.91e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0188       |
# |    n_updates            | 7770         |
# |    policy_gradient_loss | -6.19e-05    |
# |    value_loss           | 0.00144      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1e+03     |
# |    ep_rew_mean          | 2.1e+03     |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 779         |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 99712       |
# | train/                  |             |
# |    approx_kl            | 0.018203035 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 7780        |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 0.0013      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1e+03     |
# |    ep_rew_mean          | 2.1e+03     |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 780         |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 99840       |
# | train/                  |             |
# |    approx_kl            | 0.009646439 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000136   |
# |    n_updates            | 7790        |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 0.000884    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.08e+03     |
# |    ep_rew_mean          | 2.08e+03     |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 781          |
# |    time_elapsed         | 431          |
# |    total_timesteps      | 99968        |
# | train/                  |              |
# |    approx_kl            | 0.0034071603 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.827       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0192      |
# |    n_updates            | 7800         |
# |    policy_gradient_loss | -0.00559     |
# |    value_loss           | 0.000538     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.08e+03     |
# |    ep_rew_mean          | 2.08e+03     |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 782          |
# |    time_elapsed         | 432          |
# |    total_timesteps      | 100096       |
# | train/                  |              |
# |    approx_kl            | 0.0002849619 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | -0.0032      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 167          |
# |    n_updates            | 7810         |
# |    policy_gradient_loss | 0.000318     |
# |    value_loss           | 622          |
# ------------------------------------------
# ✅ Logs saved to lifesim_training_results.csv
