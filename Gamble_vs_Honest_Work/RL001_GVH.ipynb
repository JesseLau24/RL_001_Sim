# %%
# 完整最终版 LifeSimEnv
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd

class LifeSimEnv(gym.Env):
    metadata = {"render.modes": ["human"]}

    def __init__(self,
                 init_cash=10000,
                 init_health=100,
                 max_days=365*80,
                 labor_income=100,
                 labor_health_loss=1,
                 spec_gain=500,
                 spec_loss=700,
                 spec_prob=0.5,
                 spec_health_loss=0.5,
                 rest_recover=2,
                 deposit_rate=0.0001,
                 debt_rate=0.0005):

        super(LifeSimEnv, self).__init__()

        # === 参数 ===
        self.init_cash = init_cash
        self.init_health = init_health
        self.max_days = max_days
        self.labor_income = labor_income
        self.labor_health_loss = labor_health_loss
        self.spec_gain = spec_gain
        self.spec_loss = spec_loss
        self.spec_prob = spec_prob
        self.spec_health_loss = spec_health_loss
        self.rest_recover = rest_recover
        self.deposit_rate = deposit_rate
        self.debt_rate = debt_rate

        # === 状态空间 (现金, 健康, 天数) ===
        self.observation_space = spaces.Box(
            low=np.array([-np.inf, 0, 0], dtype=np.float32),
            high=np.array([np.inf, 100, self.max_days], dtype=np.float32),
            dtype=np.float32
        )

        # === 动作空间 (0=休息, 1=劳动, 2=投机) ===
        self.action_space = spaces.Discrete(3)

        # === 内部状态 ===
        self.cash = None
        self.health = None
        self.day = None

        # 日志
        self.episode_log = None
        self.all_episode_logs = []

    def reset_episode_log(self):
        """初始化单轮 episode 日志"""
        self.episode_log = {
            "days_alive": None,  # None 表示还没活过一天
            "work_days": 0,
            "spec_days": 0,
            "rest_days": 0,
            "final_cash": None
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        # 初始化状态
        self.cash = float(self.init_cash)
        self.health = float(self.init_health)
        self.day = 0

        # 初始化日志
        self.reset_episode_log()

        obs = np.array([self.cash, self.health, self.day], dtype=np.float32)
        return obs, {}

    def step(self, action):
        self.day += 1
        reward = 1.0 + np.log1p(max(0, self.cash)) * 0.01  # 存活奖励 + 财富奖励

        # === 行为逻辑 ===
        if action == 0:  # 休息
            self.health = min(100, self.health + self.rest_recover)
            self.episode_log["rest_days"] += 1

        elif action == 1:  # 劳动
            self.cash += self.labor_income
            self.health -= self.labor_health_loss
            self.episode_log["work_days"] += 1

        elif action == 2:  # 投机
            if np.random.rand() < self.spec_prob:
                self.cash += self.spec_gain
            else:
                self.cash -= self.spec_loss
            self.health -= self.spec_health_loss
            self.episode_log["spec_days"] += 1

        # === 利息计算 ===
        if self.cash > 0:
            self.cash *= (1 + self.deposit_rate)
        elif self.cash < 0:
            self.cash *= (1 + self.debt_rate)

        # === 更新日志 ===
        self.episode_log["days_alive"] = self.day
        self.episode_log["final_cash"] = self.cash

        # === 状态 ===
        obs = np.array([self.cash, self.health, self.day], dtype=np.float32)

        # === 检查是否结束 ===
        done = False
        if self.health <= 0 or self.day >= self.max_days:
            done = True
            # ✅ 只在 episode 真正结束时记录日志，避免存 0 值
            self.record_episode()

        truncated = False
        return obs, reward, done, truncated, {}

    def render(self, mode="human"):
        print(f"Day {self.day} | Cash: {self.cash:.2f} | Health: {self.health:.1f}")

    def record_episode(self):
        """保存当前 episode 日志"""
        if self.episode_log is not None and self.episode_log["days_alive"] is not None:
            self.all_episode_logs.append(self.episode_log.copy())

    def save_logs_to_csv(self, filename="life_logs.csv"):
        """保存所有 episode 日志到 CSV"""
        if len(self.all_episode_logs) == 0:
            print("⚠️ 没有日志可保存！")
            return
        df = pd.DataFrame(self.all_episode_logs)
        df.to_csv(filename, index=False)
        print(f"✅ Logs saved to {filename}")

# %%
# 第二个 cell: 训练 RecurrentPPO 智能体，并记录每轮人生

import torch
from stable_baselines3 import PPO
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor

# === 1. 包装环境，使用 DummyVecEnv ===
def make_env():
    return LifeSimEnv()

env = DummyVecEnv([make_env])
env = VecMonitor(env)  # 自动记录 episode reward 等信息

# === 2. 定义 RecurrentPPO 智能体 ===
policy_kwargs = dict(
    net_arch=[64, 64],  # LSTM 前的 MLP 层
    lstm_hidden_size=64,
    n_lstm_layers=1,
)

model = RecurrentPPO(
    "MlpLstmPolicy",
    env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    batch_size=32,
    n_steps=128,       # 每个 rollout 的步数
    learning_rate=3e-4,
    gamma=0.99,
    device="cuda"
)

# === 3. 自定义 Callback，用于记录每轮人生 ===
from stable_baselines3.common.callbacks import BaseCallback

class EpisodeLoggerCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_rollout_end(self):
        # rollout 结束时，不记录，这里主要在每个 episode done 时记录
        pass

    def _on_step(self) -> bool:
        # 检查每个 env 是否 done
        infos = self.locals.get("infos", [])
        for i, info in enumerate(infos):
            if "episode" in info:
                # episode done，调用环境记录日志
                self.training_env.envs[i].record_episode()
        return True

callback = EpisodeLoggerCallback()

# === 4. 开始训练 ===
total_timesteps = 100_000  # 可以根据算力调整
model.learn(total_timesteps=total_timesteps, callback=callback)

# === 5. 训练结束后，保存模型和日志 ===
model.save("lifesim_recurrentppo")

# 保存日志到 CSV
env.envs[0].save_logs_to_csv("lifesim_training_results.csv")
# Out:
# Using cpu device
# ----------------------------
# | time/              |     |
# |    fps             | 494 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 128 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0017134263 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -2.43e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.1         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.000357     |
# |    value_loss           | 231          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 384          |
# | train/                  |              |
# |    approx_kl            | 0.0019364445 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.317        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 205          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0016461881 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.115       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 88.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00589     |
# |    value_loss           | 181          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 640          |
# | train/                  |              |
# |    approx_kl            | 0.0010917429 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.106       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 188          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 6             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 0.00083956914 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0.00998       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 67.5          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 1.94e-05      |
# |    value_loss           | 177           |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 281        |
# |    iterations           | 7          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 896        |
# | train/                  |            |
# |    approx_kl            | 0.00928321 |
# |    clip_fraction        | 0.0328     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.00404    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 93.9       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00436   |
# |    value_loss           | 176        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.003158486 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1152        |
# | train/                  |             |
# |    approx_kl            | 0.010252696 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00342    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 168         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 10          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.008273968 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.00177     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 165         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 11          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.008095159 |
# |    clip_fraction        | 0.00547     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00157     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 161         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 12          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.010905171 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | -0.000652   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.1        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00592    |
# |    value_loss           | 158         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 13           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0011492237 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | 0.00541      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.8         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000479    |
# |    value_loss           | 155          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 14          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.005065661 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.0059      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.3        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 152         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 15          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 1920        |
# | train/                  |             |
# |    approx_kl            | 0.015232883 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.000508    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.5        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00728    |
# |    value_loss           | 148         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 16          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008963881 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 7.03e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84          |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 145         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 17          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 2176        |
# | train/                  |             |
# |    approx_kl            | 0.004006256 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 18          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.011982341 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000557   |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 19           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 2432         |
# | train/                  |              |
# |    approx_kl            | 0.0042442703 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.5         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 136          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 288        |
# |    iterations           | 20         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.00667092 |
# |    clip_fraction        | 0.0414     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.91      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 60.6       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.003     |
# |    value_loss           | 134        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 21           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 2688         |
# | train/                  |              |
# |    approx_kl            | 0.0024614925 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.913       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.9         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000249    |
# |    value_loss           | 131          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 22           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 0.0009321347 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.885       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.4         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00027      |
# |    value_loss           | 128          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 288           |
# |    iterations           | 23            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 2944          |
# | train/                  |               |
# |    approx_kl            | 0.00081557175 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.89         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 72.1          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 0.000155      |
# |    value_loss           | 125           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 24           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0044344417 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.926       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.5         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00451     |
# |    value_loss           | 122          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 25          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.007794234 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.7        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 26          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.014832191 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.9        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 27          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 3456        |
# | train/                  |             |
# |    approx_kl            | 0.005269011 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.6        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 28          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.005575957 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.2        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 29          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3712        |
# | train/                  |             |
# |    approx_kl            | 0.009775039 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.00399     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 109         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 292           |
# |    iterations           | 30            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 3840          |
# | train/                  |               |
# |    approx_kl            | 0.00011844048 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.702        |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.8          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.000495      |
# |    value_loss           | 107           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 31          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 3968        |
# | train/                  |             |
# |    approx_kl            | 0.006032204 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.000117    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 104         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 294           |
# |    iterations           | 32            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00014138967 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.582        |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 58            |
# |    n_updates            | 310           |
# |    policy_gradient_loss | 0.00074       |
# |    value_loss           | 102           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 33          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4224        |
# | train/                  |             |
# |    approx_kl            | 0.004553791 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 99.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 34          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.004965455 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.442      |
# |    explained_variance   | 1.91e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 96.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 35           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4480         |
# | train/                  |              |
# |    approx_kl            | 0.0017062039 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.477       |
# |    explained_variance   | 0.00107      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.5         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 94.7         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 36         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.00062752 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.478     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.2       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -8.28e-05  |
# |    value_loss           | 92.2       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 37           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4736         |
# | train/                  |              |
# |    approx_kl            | 0.0011078487 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 1.16e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.2         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 89.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 38           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0015120548 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 4.71e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.3         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000456    |
# |    value_loss           | 87.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 39          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4992        |
# | train/                  |             |
# |    approx_kl            | 0.000222011 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.48       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34          |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 5.75e-05    |
# |    value_loss           | 85.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 40           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0030143536 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.5         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 83.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 41          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 0.002960735 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44          |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000683   |
# |    value_loss           | 81          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 42          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.005110986 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.533      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 78.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 43           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 5504         |
# | train/                  |              |
# |    approx_kl            | 0.0036503146 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 1.85e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.4         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 76.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 44           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0053464198 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.9         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000882    |
# |    value_loss           | 74.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 45           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 5760         |
# | train/                  |              |
# |    approx_kl            | 0.0035874746 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.000185     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.2         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 72.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 46           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0029531112 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.000134     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.5         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 70.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 47          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6016        |
# | train/                  |             |
# |    approx_kl            | 0.006287067 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 68.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 48           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0019746064 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.3         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 66.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 49           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6272         |
# | train/                  |              |
# |    approx_kl            | 0.0010618237 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.00017      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.2         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000268     |
# |    value_loss           | 64.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 50           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0018426301 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 62.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 51           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 6528         |
# | train/                  |              |
# |    approx_kl            | 0.0020466377 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.662       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31           |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 60.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 52           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0041560614 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.6         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 59.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 53           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 6784         |
# | train/                  |              |
# |    approx_kl            | 0.0030587823 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00549     |
# |    value_loss           | 57.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 54           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0011496395 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 55.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 55           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 7040         |
# | train/                  |              |
# |    approx_kl            | 0.0030837897 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18           |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 53.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 56           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0036805915 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 52           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 57           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 7296         |
# | train/                  |              |
# |    approx_kl            | 0.0024237134 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 1.32e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.2         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 50.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 58          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.002450978 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.626      |
# |    explained_variance   | 0.000218    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 48.7        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 59            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 7552          |
# | train/                  |               |
# |    approx_kl            | 0.00020318525 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.653        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 17.8          |
# |    n_updates            | 580           |
# |    policy_gradient_loss | 0.00033       |
# |    value_loss           | 47            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 60           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0068485667 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.5         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 45.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 302           |
# |    iterations           | 61            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 7808          |
# | train/                  |               |
# |    approx_kl            | 0.00027560303 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.74         |
# |    explained_variance   | 0.000127      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.69          |
# |    n_updates            | 600           |
# |    policy_gradient_loss | 0.000923      |
# |    value_loss           | 43.9          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 62           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 7936         |
# | train/                  |              |
# |    approx_kl            | 0.0046780915 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.7         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | 0.00122      |
# |    value_loss           | 42.2         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 63         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 8064       |
# | train/                  |            |
# |    approx_kl            | 0.00432468 |
# |    clip_fraction        | 0.0211     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.732     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20         |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.00211   |
# |    value_loss           | 40.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 64          |
# |    time_elapsed         | 27          |
# ...
# |    fps                  | 173          |
# |    iterations           | 765          |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 97920        |
# | train/                  |              |
# |    approx_kl            | 0.0005908781 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0.00088      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 7640         |
# |    policy_gradient_loss | -0.000218    |
# |    value_loss           | 507          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 766          |
# |    time_elapsed         | 566          |
# |    total_timesteps      | 98048        |
# | train/                  |              |
# |    approx_kl            | 0.0007475531 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.706       |
# |    explained_variance   | 0.00109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 230          |
# |    n_updates            | 7650         |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 489          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 767          |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 98176        |
# | train/                  |              |
# |    approx_kl            | 0.0033479542 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.731       |
# |    explained_variance   | 0.00122      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.1          |
# |    n_updates            | 7660         |
# |    policy_gradient_loss | -0.000456    |
# |    value_loss           | 474          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 768         |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.000953367 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.0013      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.28        |
# |    n_updates            | 7670        |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 449         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 769         |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 98432       |
# | train/                  |             |
# |    approx_kl            | 0.010807309 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.00129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 853         |
# |    n_updates            | 7680        |
# |    policy_gradient_loss | 0.00122     |
# |    value_loss           | 441         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 770         |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 98560       |
# | train/                  |             |
# |    approx_kl            | 0.045298725 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0579      |
# |    n_updates            | 7690        |
# |    policy_gradient_loss | -0.000331   |
# |    value_loss           | 3.87        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 771          |
# |    time_elapsed         | 570          |
# |    total_timesteps      | 98688        |
# | train/                  |              |
# |    approx_kl            | 0.0064725433 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.769       |
# |    explained_variance   | 0.000431     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0372       |
# |    n_updates            | 7700         |
# |    policy_gradient_loss | 0.0062       |
# |    value_loss           | 211          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 772         |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 98816       |
# | train/                  |             |
# |    approx_kl            | 0.002261371 |
# |    clip_fraction        | 0.00234     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.000323    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0164      |
# |    n_updates            | 7710        |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 179         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 109           |
# |    ep_rew_mean          | 119           |
# | time/                   |               |
# |    fps                  | 173           |
# |    iterations           | 773           |
# |    time_elapsed         | 571           |
# |    total_timesteps      | 98944         |
# | train/                  |               |
# |    approx_kl            | 0.00075201504 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.754        |
# |    explained_variance   | 0.000508      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.7           |
# |    n_updates            | 7720          |
# |    policy_gradient_loss | -0.00158      |
# |    value_loss           | 530           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 109           |
# |    ep_rew_mean          | 120           |
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 774           |
# |    time_elapsed         | 572           |
# |    total_timesteps      | 99072         |
# | train/                  |               |
# |    approx_kl            | 0.00017357944 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.746        |
# |    explained_variance   | 0.000556      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 400           |
# |    n_updates            | 7730          |
# |    policy_gradient_loss | 4.53e-05      |
# |    value_loss           | 569           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 110           |
# |    ep_rew_mean          | 120           |
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 775           |
# |    time_elapsed         | 573           |
# |    total_timesteps      | 99200         |
# | train/                  |               |
# |    approx_kl            | 0.00051230425 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.73         |
# |    explained_variance   | 0.00042       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 146           |
# |    n_updates            | 7740          |
# |    policy_gradient_loss | 0.000652      |
# |    value_loss           | 557           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 110           |
# |    ep_rew_mean          | 120           |
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 776           |
# |    time_elapsed         | 574           |
# |    total_timesteps      | 99328         |
# | train/                  |               |
# |    approx_kl            | 0.00055784965 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.698        |
# |    explained_variance   | 0.000466      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.84          |
# |    n_updates            | 7750          |
# |    policy_gradient_loss | -0.00335      |
# |    value_loss           | 588           |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 110        |
# |    ep_rew_mean          | 120        |
# | time/                   |            |
# |    fps                  | 172        |
# |    iterations           | 777        |
# |    time_elapsed         | 575        |
# |    total_timesteps      | 99456      |
# | train/                  |            |
# |    approx_kl            | 0.00746336 |
# |    clip_fraction        | 0.0203     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.699     |
# |    explained_variance   | 0.000422   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.2e+03    |
# |    n_updates            | 7760       |
# |    policy_gradient_loss | -0.0011    |
# |    value_loss           | 594        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 172          |
# |    iterations           | 778          |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 99584        |
# | train/                  |              |
# |    approx_kl            | 0.0019585826 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.732       |
# |    explained_variance   | 0.000322     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0273       |
# |    n_updates            | 7770         |
# |    policy_gradient_loss | 0.00124      |
# |    value_loss           | 554          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 172          |
# |    iterations           | 779          |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 99712        |
# | train/                  |              |
# |    approx_kl            | 0.0014329064 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.709       |
# |    explained_variance   | 0.00031      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0274       |
# |    n_updates            | 7780         |
# |    policy_gradient_loss | 4.27e-06     |
# |    value_loss           | 587          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 780         |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 99840       |
# | train/                  |             |
# |    approx_kl            | 0.032513894 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.000337    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 599         |
# |    n_updates            | 7790        |
# |    policy_gradient_loss | 0.00364     |
# |    value_loss           | 651         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 111        |
# |    ep_rew_mean          | 122        |
# | time/                   |            |
# |    fps                  | 172        |
# |    iterations           | 781        |
# |    time_elapsed         | 578        |
# |    total_timesteps      | 99968      |
# | train/                  |            |
# |    approx_kl            | 0.01571361 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.791     |
# |    explained_variance   | 0.00031    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.23e+03   |
# |    n_updates            | 7800       |
# |    policy_gradient_loss | 0.00411    |
# |    value_loss           | 671        |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 112           |
# |    ep_rew_mean          | 122           |
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 782           |
# |    time_elapsed         | 579           |
# |    total_timesteps      | 100096        |
# | train/                  |               |
# |    approx_kl            | 0.00049751624 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.799        |
# |    explained_variance   | 0.000349      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 254           |
# |    n_updates            | 7810          |
# |    policy_gradient_loss | -0.00117      |
# |    value_loss           | 654           |
# -------------------------------------------
# ✅ Logs saved to lifesim_training_results.csv
